# %%
import keras
import numpy
import utils
import metrics
import models_preprocessing
from keras.preprocessing.image import ImageDataGenerator

import matplotlib.pyplot as plt
import matplotlib.image as img
import numpy as np
from scipy.misc import imresize

# %matplotlib inline

import os
from os import listdir
from os.path import isfile, join
# Out:
# Using TensorFlow backend.

# %%
import multiprocessing as mp

num_processes = 6
pool = mp.Pool(processes=num_processes)

# %%
auroc = metrics.auroc

reg_convnet = models_preprocessing.compiledRegularizedConvnet 

data = numpy.load('data/imadjust.npy')

labels = numpy.load('labels/classification.npy')

train_datagen = ImageDataGenerator(featurewise_center=True, featurewise_std_normalization=True, rotation_range=90, 
                               horizontal_flip=False)

#train_generator = train_datagen.flow(data, labels, batch_size=32, seed=11, pool=pool)


utils.epoch_curve_generator(reg_convnet, data, labels, train_datagen, 32, 0.3, range(1,30), auroc)
# Out:
# 14000
# Epoch 1/1
# 437/437 [==============================] - 36s - loss: 26.9770 - acc: 0.6593
# Epoch 1/1
# 437/437 [==============================] - 34s - loss: 0.4439 - acc: 0.8176
# Epoch 1/1
# Epoch 1/1
# 282/437 [==================>...........] - ETA: 12s - loss: 0.4127 - acc: 0.8362
