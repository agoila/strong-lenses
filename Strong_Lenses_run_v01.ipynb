# %%
from models_preprocessing import compiledConvnet
from metrics import basicTextMetrics, auroc, accuracy
import utils
import numpy as np

# %%
X = 'Simulated_Data/imadjust.npy'
Y = 'Simulated_Data/classification.npy'

# Split into training, testing and validation sets

# %%
utils.train(compiledConvnet(), 1, X, Y)
# Out:
# Epoch 1/1
# 20000/20000 [==============================] - 12s - loss: 0.5472 - acc: 0.7432

# %%
utils.cross_validation(compiledConvnet, X, Y, numFolds=5, num_epochs=12, basicTextMetrics())
