# %%
import keras
import numpy
import utils
import metrics
import models_preprocessing
from keras.preprocessing.image import ImageDataGenerator
# Out:
# Using TensorFlow backend.

# %%
auroc = metrics.auroc
data = numpy.load('Simulated_Data/wiener2.npy')
labels = numpy.load('Simulated_Data/classification.npy')
#comp_convnet = models_preprocessing.compiledConvnet

# %%
utils.epoch_curve(models_preprocessing.compiledConvnet, data, labels, 0.3, range(1,30), auroc)
# Out:
# Epoch 1/1
# 14000/14000 [==============================] - 7s - loss: 0.5325 - acc: 0.7581
# Epoch 1/1
# 14000/14000 [==============================] - 6s - loss: 0.3833 - acc: 0.8276
# Epoch 1/1
# 14000/14000 [==============================] - 6s - loss: 0.3256 - acc: 0.8551
# Epoch 1/1
# 13248/14000 [===========================>..] - ETA: 0s - loss: 0.2853 - acc: 0.8767
